# %%
i=int(input)
for(i=0;i<n;i++):
    for(j=0;j<n-i-1;j++):
        print(" ")
            for(j=0;j<2*i+1;j++):
                print("*")
                    for(j=0;j<n-i-1;j++):
                        print(" ")
# Out:
#   Cell In[2], line 2
#     for(i=0;i<n;i++):
#         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
a="vysh"
b="navi"
c="vysh"
for a in (b,c):
    print("True")
# Out:
# True
# True

# %%
numbers=[10,20,30,40]
total=sum(numbers)
print("Total sum=",total)
halfsum=total/2
print("half sum=",halfsum)
numbers=[int(halfsum)*len(numbers)]
print(numbers)
# Out:
# Total sum= 100
# half sum= 50.0
# [200]
