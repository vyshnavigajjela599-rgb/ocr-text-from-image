# %%
i=int(input)
for(i=0;i<n;i++):
    for(j=0;j<n-i-1;j++):
        print(" ")
            for(j=0;j<2*i+1;j++):
                print("*")
                    for(j=0;j<n-i-1;j++):
                        print(" ")
# Out:
#   Cell In[2], line 2
#     for(i=0;i<n;i++):
#         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
